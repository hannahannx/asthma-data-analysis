# %% [markdown]
# # Data Modelling and Visualisation

# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# ## Importing Modules

# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import linear_model
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load data set

# %%
df = pd.read_csv('../data/cleaned_data/cleaned_datasetIMPORTED.csv')

# %% [markdown]
# ## Independent and Dependent Varibles

# %%
# Independent
X = df[["Paediatric Asthma Admissions Per 1000 Admissions","FY1/2 - Total Repository Staff Posts"]]
# Dependent
y = df[["FY1/2 -Filled Respiratory Staff Posts"]]

# %% [markdown]
# # Training and Test splits

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ## Relationship

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predict the amount of Respiratory staff needed

# %%
y_predictions = regr.predict(X_test)
print("Predicted Filled Staff Posts ", y_predictions) # round the number up because you cant hav e afloat of a staff
# Out:
# Predicted Filled Staff Posts  [[5.55542792]
#  [6.03153269]
#  [5.9941947 ]
#  [6.95840574]
#  [6.03153269]
#  [6.20424359]
#  [5.55542792]
#  [6.44096247]
#  [6.01686419]
#  [5.75480881]
#  [6.19090859]
#  [6.0048627 ]
#  [5.9595237 ]
#  [5.79348031]
#  [5.9968617 ]
#  [6.46096497]
#  [6.03153269]
#  [6.93440275]
#  [6.0035292 ]
#  [5.9555232 ]
#  [5.72280481]
#  [5.77614481]
#  [5.76147631]
#  [5.76947731]
#  [6.48096747]
#  [5.76947731]
#  [6.19757609]
#  [6.49163547]
#  [6.44629647]]

# %%
print("Coefficients of Asthma admissions per 1000 and total respitory staff posts againsed the total number of filled post :", regr.coef_)
# Out:
# Coefficients of Asthma admissions per 1000 and total respitory staff posts againsed the total number of filled post : [[-0.0013335   0.23805239]]

# %%
plt.scatter(y_test, y_predictions)
plt.plot(y_test, y_predictions)
sns.regplot(X,y)

m, b = np.polyfit(y_test, y_predictions,1)
plt.plot(X, m*X + b)


plt.scatter(y_predictions, y_predictions)
plt.plot(y_test, y_predictions)
plt.xlabel(y_test)
plt.ylabel(y_predictions)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 plt.scatter(y_test, y_predictions)
#       2 plt.plot(y_test, y_predictions)
# ----> 3 sns.regplot(X,y)
#       5 m, b = np.polyfit(y_test, y_predictions,1)
#       6 plt.plot(X, m*X + b)
#
# TypeError: regplot() takes from 0 to 1 positional arguments but 2 were given
